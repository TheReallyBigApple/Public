# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <br><br><br><br>
#
# <center><strong>Bar Charts</strong></center>
# <br><br>
# Bar charts display a key value of category:value
#
# In this case, its
# <table>
# <tr>
#     <td>Nuclear</td>
#     <td>5</td>
# </tr>
# <tr>
#     <td>Hydro</td>
#     <td>6</td>
# </tr>
# <tr>
#     <td>Gas</td>
#     <td>15</td>
# </tr>
# </table>
# <br><br><br><br>

# %%
# plt.style.use('ggplot')        # looks the same either way

x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy = [5, 6, 15, 22, 24, 8]

# x_pos = [i for i, _ in enumerate(x)]

plt.bar(x, energy, color='green')
# plt.bar(x_pos, energy, color='green')   # converting to int also had no effect
plt.xlabel("Energy Source")
plt.ylabel("Energy Output (GJ)")
plt.title("Energy output from various fuel sources")

# plt.xticks(x_pos, x)             # dont need this either

plt.show()

# %% [markdown]
# <br><br><br><br>
# <center><strong>Bar Charts - Horizontal with Error Bars</strong></center>
# <br><br>
#
# To make it horizontal, use barh()
# <br>
# Surprisingly, you dont need to flip the x and y values that feed barh()
# <br>
# However, you do need to flip the xlabel and ylabel and..
# <br>
# If you use barh(), then you want to set xerr
# <br>
# If you use bar(), then you want to set yerr
#
# To generate an error bar with different upper and lower values, use errorbar()
# <br><br><br><br>

# %%
x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy = [5, 6, 15, 22, 24, 8]

var1 = [1, 3, 3, 4, 2, 3]
var2 = [3, 9, 4, 6, 2, 1]

x_pos = [i for i, _ in enumerate(x)]

plt.barh(x_pos, energy, color='green')
plt.errorbar(energy, x_pos, xerr=[var1,var2],fmt='o',ecolor = 'red',color='yellow') 

plt.xlabel("Energy Source")
plt.ylabel("Energy Output (GJ)")

plt.title("Energy output from various fuel sources")


plt.show()

# %% [markdown]
# <br><br><br><br>
# <center><strong>Bar Charts with multiple Xs </strong></center>
# <br><br>
#
# To put x's by category with legend. Note the width of 5. allows no space in between.
#
# Note how "ind + width" governs both xticks() and the second plt.bar()
# <br><br><br><br>

# %%
N = 5
men_means = (20, 35, 30, 35, 27)
women_means = (25, 32, 34, 20, 25)

ind = np.arange(N)       # [0 1 2 3 4]

width = 0.4       
plt.bar(ind, men_means, width, label='Men')
plt.bar(ind + width, women_means, width,
    label='Women')

plt.ylabel('Scores')
plt.title('Scores by group and gender')

plt.xticks(ind + width / 2, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Bar Chart with Colors

# %%
dict = {'A': 40, 'B': 70, 'C': 30, 'D': 85}

for i, key in enumerate(dict):
    plt.bar(i, dict[key])
    
plt.xticks(np.arange(len(dict))+0.4, dict.keys())
plt.show()

# %% [markdown]
# The width parameter allows you to control the white space.
# <br>
# Note randn(x) and rand(x) both produce x random numbers.
# <br>
# rand(x) is uniformally between 0 and 1
# <br>
# randn(x) is normally distributed so its mostly betwen -1 and 1
# <br>
# Take the absolute of randn(x) times .5, you get values centered around .5

# %%
# create 3 random data sets
data1=10*np.random.rand(5)
data2=10*np.random.rand(5)
data3=10*np.random.rand(5)
e2 = 0.5 * np.abs(np.random.randn(len(data2)))   # [0.5208804  0.50212433 0.22970618 0.13563249 0.0577361 ]
locs = np.arange(1, len(data1)+1)       # 1,2,3,4,5
width = 0.2
plt.bar(locs, data1, width=width)
plt.bar(locs+width, data2, yerr=e2, width=width, color='red')
plt.bar(locs+2*width, data3, width=width, color='green')
plt.xticks(locs + width*1.5, locs)

plt.show()

# %% [markdown]
# <br><br><br><br>
# <center><strong>Stacked Bar Charts</strong></center>
# <br><br>
#
# The other way of dealing with x's by category with legend.
# <br>
# The "bottom" keyword invokes the stack. It says this is where the bottom *goes*.
# <br>
# Note width of .8 allows as much space as .4 did previously.
# <br>
# Note how "ind + width" governs both xticks() and the second plt.bar()
# <br><br><br><br>

# %%
countries = ['USA', 'GB', 'China', 'Russia', 'Germany']
bronzes = np.array([38, 17, 26, 19, 15])
silvers = np.array([37, 23, 18, 18, 10])
golds = np.array([46, 27, 26, 19, 17])
ind = [x for x, _ in enumerate(countries)]    # [0, 1, 2, 3, 4]

plt.bar(ind, golds, width=0.8, label='golds', color='gold', bottom=silvers+bronzes)
plt.bar(ind, silvers, width=0.8, label='silvers', color='silver', bottom=bronzes)
plt.bar(ind, bronzes, width=0.8, label='bronzes', color='#CD853F')

plt.xticks(ind, countries)
plt.ylabel("Medals")
plt.xlabel("Countries")
plt.legend(loc="upper right")
plt.title("2012 Olympics Top Scorers")

plt.show()

# %% [markdown]
# <br><br><br><br>
#
# <center><strong>Histograms</strong></center>
# <br><br>
# Note plt.hist(y,25) is the same as plt.hist(y,bins=25)
# <br>
# plt.show() is platform dependent
# if you call plt.hist, youll see stuf like
#     <BarContainer object of 25 artists>) and more
# plt.show() will just display the plot
# also note %matplotlib inline is one of several "magic" functions that
# helps control how plots are shown but here it doesnt seem to have an effect
# <br><br><br><br>

# %%
y = np.random.randn(1000)

plt.hist(y, bins=25)
plt.show()

# %% [markdown]
# Histogram with mean, std dev, and a best fit line. Call plt.hist and plt.plot

# %%
grp_exp = np.array([12,  15,  13,  20,  19,  20,  11,  19,  11,  12,  19,  13,  
                    12,  10,  6,  19,  3,  1,  1,  0,  4,  4,  6,  5,  3,  7,  
                    12,  7,  9,  8,  12,  11,  11,  18,  19,  18,  19,  3,  6,  
                     5,  6,  9,  11,  10,  14,  14,  16,  17,  17,  19,  0,  2,  
                     0,  3,  1,  4,  6,  6,  8,  7,  7,  6,  7,  11,  11,  10,  
                    11,  10,  13,  13,  15,  18,  20,  19,  1,  10,  8,  16,  
                    19,  19,  17,  16,  11,  1,  10,  13,  15,  3,  8,  6,  9,  
                    10,  15,  19,  2,  4,  5,  6,  9,  11,  10,  9,  10,  9,  
                    15,  16,  18,  13])
# Plot the distribution of Experience
nbins = 21
n, bins, patches = plt.hist(grp_exp, bins = nbins, density=1)
# Add axis labels
plt.xlabel("Experience in years")
plt.ylabel("Percentage")
plt.title("Distribution of Experience in a Lateral Training Program")
mu = grp_exp.mean()
sigma = grp_exp.std()
# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins, y, '--')
plt.show()

# Statistics of DSS Batch experience
print("Mean Experience of DSS Batch: {:4.3f}".format(grp_exp.mean()))
print("Std Deviation of Experience of DSS Batch: {:4.3f}".format(grp_exp.std()))
# Out:
# Mean Experience of DSS Batch: 10.435
# Std Deviation of Experience of DSS Batch: 5.665

# %%
baseline = (abs(np.random.logistic(loc=2, scale=3, size=(20))))
# [2.5674703  4.4849041  1.69695818 3.09205522 1.8395827  8.24169024  1.35649817 0.70995104]
plt.hist(baseline, density=False, bins=30)  
plt.gca().set(title="Baseline Performance Distribution")  
plt.ylabel('Freq (%)')
plt.xlabel('Milliseconds');

# %% [markdown]
# the lower the alpha the more transparent it is

# %%
plt.style.use('seaborn-white')     
data = np.random.randn(1000)       
plt.hist(data, bins=30,  alpha=0.5,
                histtype='stepfilled', 
                color='steelblue',
                edgecolor='none');

# %% [markdown]
# colors get applied automatically

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

# kwargs = dict(histtype='stepfilled', alpha=0.3, bins=40)
kwargs = {"histtype" : "stepfilled", "alpha" : 0.3, "bins" : 40}
# kwargs = {"alpha" : 0.3, "bins" : 40}

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
plt.show()

# %% [markdown]
# Use subplots to put side by side
# first 2 parameters are nrows and ncols
# sharey=True means only display y axis once, they will share the taller y axis,
# and as a result, one of the peaks may not reach the top

# %%
N_points = 100000
n_bins = 20

np.random.seed(10)

# Generate a normal distribution, center at x=0 and y=5
x = np.random.randn(N_points)
y = .4 * x + np.random.randn(100000) + 5

# fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
fig, axs = plt.subplots(nrows=1, ncols=2, sharey=True, tight_layout=True)
# We can set the number of bins with the `bins` kwarg
axs[0].hist(x, bins=n_bins)
axs[1].hist(y, bins=n_bins)
plt.show()

# %% [markdown]
# barh() to do a horizontal bar chart
#
# twinx and twiny to matchup the axis from two axes

# %%
from matplotlib.ticker import MultipleLocator

fig = plt.figure(figsize=(10,6))
ax1 = plt.subplot(121)
ax2 = ax1.twinx()        # share x axis

ax3 = plt.subplot(122)
ax4 = ax3.twiny()       # share y axis

x = [0, 1, 2, 3, 4, 5]
y = [19, 12, 6, 4, 3, 2]
y1 = [41, 67, 80, 89, 96, 100]

b = ax1.bar(x, y, label='Number of Defects')
l, = ax2.plot(x, y1, color='g', lw=5, label='Cumulative Defects as %')

majorLocator = MultipleLocator(2)
ax1.yaxis.set_major_locator(majorLocator)
ax1.set(xlabel='Defect Reason Codes', ylabel='Number of Defects')

ax2.set(ylabel='Cumulative Defects as %')
ax1.legend([b, l], ['Number of Defects', 'Cumulative Defects as %'], loc=5)

b1 = ax3.barh(x, y, label='Number of Defects')
l1, = ax4.plot(y1, x, color='g', lw=5, label='Cumulative Defects as %')

ax3.xaxis.set_major_locator(majorLocator)
ax3.set(xlabel='Number of Defects', ylabel='Defect Reason Codes')
ax4.set(xlabel='Cumulative Defects as %')
ax3.legend([b1, l1], ['Number of Defects', 'Cumulative Defects as %'], loc=1)
ax3.set_ylim(-1,6)

plt.suptitle('Product Defects - August 2018', fontname='arial', fontsize=20, fontweight='bold')
plt.tight_layout(w_pad=5, pad=3)

plt.show();
